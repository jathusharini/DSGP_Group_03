# %% [markdown]
# <a href="https://colab.research.google.com/github/jathusharini/DSGP_Group_03/blob/main/Final_MediaPipeSSL_Pickle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing and importing necessary libraries


import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import pickle
import tensorflow as tf
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.preprocessing import LabelEncoder

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# Giving list of words
words = ['angry','bank', 'brother','bye','excuse me','father', 'good evening', 'good morning', 'good night', 'happy','hello', 'help','home', 'hospital','how much', 'hungry','love', 'mother', 'police station', 'sad', 'school', 'sister','sorry','thankyou', 'welcome', 'what', 'when', 'where', 'who','why']
len(words)
# Out:
# 30

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands
dic = {}
with mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5) as hands:
    for word in words:
        dire = os.path.join('/content/drive/MyDrive/MediaPipe_Data/Dataset_MediPipe/src_2', word)
        vids = os.listdir(dire)
        vid_no = 0
        print(word)
        dic[word] = []
        for i,vid in enumerate(vids):
            dic[word].append([])
            vidcap = cv2.VideoCapture(os.path.join('/content/drive/MyDrive/MediaPipe_Data/Dataset_MediPipe/src_2', word, vid))
            success,frame = vidcap.read()
            count = 0
            while success:     
                success,frame = vidcap.read()
                if success:
                    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                    results = hands.process(image)
                    if results.multi_hand_landmarks:
                        # Loop through each hand landmark in the list
                        for hand_landmarks in results.multi_hand_landmarks:
                            # Get the landmarks for the hand
                            landmarks = hand_landmarks.landmark
                            landmarks_array = np.array([[landmark.x, landmark.y, landmark.z] for landmark in landmarks])
                            # Store the landmarks in the dataset array                             
                            dic[word][i].append(landmarks_array.flatten())
                            # Draw the hand landmarks on the image for visualization
                            mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
                
            vid_no +=1

# create a binary pickle file 
#f = open()
#pickle.dump(dic,f)
#print("Successfuly transfered")
#f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30308\4027427270.py in <module>
#       5     for word in words:
#       6         dire = os.path.join('/content/drive/MyDrive/MediaPipe_Data/Dataset_MediPipe/src_2', word)
# ----> 7         vids = os.listdir(dire)
#       8         vid_no = 0
#       9         print(word)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/drive/MyDrive/MediaPipe_Data/Dataset_MediPipe/src_2\\angry'

# %% [markdown]
# Start running from here

# %%
with open('preprocessed_model.pkl', 'rb') as f:
    data = pickle.load(f)
print("reading is successful")

def stretch(video, size):
    arr = np.array(video)
    n = len(arr)
    x = np.linspace(0, n - 1, n)
    new_x = np.linspace(0, n - 1, size)
    new_arr = np.zeros((size, len(video[0])))
    for i in range(size):
        new_arr[:, i] = np.interp(new_x, x, arr[:, i])
    
    return new_arr
# Out:
# reading is successful

# %%
for key in data.keys():
    print(key, len(data[key][1]))
# Out:
# angry 17
# bank 109
# brother 32
# bye 38
# excuse me 65
# father 31
# good evening 56
# good morning 65
# good night 74
# happy 52
# hello 34
# help 60
# home 19
# hospital 103
# how much 10
# hungry 21
# love 41
# mother 30
# police station 118
# sad 27
# school 75
# sister 24
# sorry 51
# thankyou 23
# welcome 35
# what 17
# when 29
# where 9
# who 19
# why 24

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences

src_2 = {} 
for key in data.keys():
    arr = data[key]
    src_2[key] = []
    for vid in arr:
        if len(vid) !=0 :
            src_2[key].append(stretch(vid, 63))

minn = 200
for arr in src_2.values():
    for ar in arr:
        minn = min(minn, len(ar))
        
print(minn)

src_3 = {}
for key in src_2.keys():
    if len(src_2[key]) <= 63 and len(src_2[key]) >= 10:
        src_3[key] = src_2[key]

for key in src_3.keys():
    print(key, len(src_3[key]))
# Out:
# 63
# angry 25
# bank 25
# brother 25
# bye 25
# excuse me 25
# father 25
# good evening 25
# good morning 25
# good night 25
# happy 25
# hello 25
# help 25
# home 25
# hospital 25
# how much 25
# hungry 25
# love 25
# mother 25
# police station 25
# sad 25
# school 25
# sister 25
# sorry 25
# thankyou 25
# welcome 25
# what 25
# when 25
# where 25
# who 25
# why 25

# %%
# create a binary pickle file 
f = open("/content/drive/MyDrive/MediaPipe_Data/Dataset_PKL_MediaPipe/framed_all.pkl","wb")
pickle.dump(src_3,f)
print("Successfuly transfered")
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30308\725877385.py in <module>
#       1 # create a binary pickle file
# ----> 2 f = open("/content/drive/MyDrive/MediaPipe_Data/Dataset_PKL_MediaPipe/framed_all.pkl","wb")
#       3 pickle.dump(src_3,f)
#       4 print("Successfuly transfered")
#       5 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/MediaPipe_Data/Dataset_PKL_MediaPipe/framed_all.pkl'

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

#words = src_3.keys()

words = src_2.keys()

label_map = {label:num for num, label in enumerate(words)}

print('label map: ', label_map)
# Out:
# label map:  {'angry': 0, 'bank': 1, 'brother': 2, 'bye': 3, 'excuse me': 4, 'father': 5, 'good evening': 6, 'good morning': 7, 'good night': 8, 'happy': 9, 'hello': 10, 'help': 11, 'home': 12, 'hospital': 13, 'how much': 14, 'hungry': 15, 'love': 16, 'mother': 17, 'police station': 18, 'sad': 19, 'school': 20, 'sister': 21, 'sorry': 22, 'thankyou': 23, 'welcome': 24, 'what': 25, 'when': 26, 'where': 27, 'who': 28, 'why': 29}

# %%
print("bye: ", src_3['bye'][0][0][0])
# Out:
# bye:  0.39737629890441895

# %%
sequences, labels = [], []
for word in words:
    for i,sequence in enumerate(src_3[word]):
        window = src_3[word][i][:63]
        sequences.append(np.asarray(window).astype('float32'))
        labels.append(label_map[word])
    

print('sequence shape: ', np.array(sequences).shape)

print("label shape: ", np.array(labels).shape)
# Out:
# sequence shape:  (750, 63, 63)
# label shape:  (750,)

# %%
X = np.array(sequences)

print("array shape: ", X.shape)
# Out:
# array shape:  (750, 63, 63)

# %%
y = to_categorical(labels).astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print("y_test shape: ", y_test.shape)
# Out:
# y_test shape:  (150, 30)

# %%
print("X_train shape: ", X_train.shape)
# Out:
# X_train shape:  (600, 63, 63)

# %%
from tensorflow.keras.callbacks import TensorBoard

log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %% [markdown]
# #New model
#
# * src_2 = accuracy :    (Before removing frames)
# * src_3 = accuracy : 92 (Unnessacary frames removed) : saved as "model" : Final_tf_mp_model

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
import matplotlib.pyplot as plt

# Create the model
model = tf.keras.models.Sequential([
    Conv1D(32, kernel_size=3, activation='relu', input_shape=X_train.shape[1:]),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(len(words), activation='softmax')
])

# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['categorical_accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 19/19 [==============================] - 1s 6ms/step - loss: 3.4145 - categorical_accuracy: 0.0517
# Epoch 2/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 3.2129 - categorical_accuracy: 0.0783
# Epoch 3/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 2.9987 - categorical_accuracy: 0.1650
# Epoch 4/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 2.7500 - categorical_accuracy: 0.2567
# Epoch 5/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 2.5127 - categorical_accuracy: 0.3050
# Epoch 6/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 2.3213 - categorical_accuracy: 0.3533
# Epoch 7/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 2.1139 - categorical_accuracy: 0.4183
# Epoch 8/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.9468 - categorical_accuracy: 0.4933
# Epoch 9/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.8169 - categorical_accuracy: 0.5083
# Epoch 10/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 1.6982 - categorical_accuracy: 0.5267
# Epoch 11/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6108 - categorical_accuracy: 0.5583
# Epoch 12/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5155 - categorical_accuracy: 0.5817
# Epoch 13/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3974 - categorical_accuracy: 0.6400
# Epoch 14/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2949 - categorical_accuracy: 0.6433
# Epoch 15/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2832 - categorical_accuracy: 0.6400
# Epoch 16/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2186 - categorical_accuracy: 0.6633
# Epoch 17/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1153 - categorical_accuracy: 0.7117
# Epoch 18/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0974 - categorical_accuracy: 0.6967
# Epoch 19/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0513 - categorical_accuracy: 0.7133
# Epoch 20/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9797 - categorical_accuracy: 0.7600
# Epoch 21/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9732 - categorical_accuracy: 0.7417
# Epoch 22/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9164 - categorical_accuracy: 0.7950
# Epoch 23/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8698 - categorical_accuracy: 0.7850
# Epoch 24/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8513 - categorical_accuracy: 0.7767
# Epoch 25/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8315 - categorical_accuracy: 0.7733
# Epoch 26/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.8128 - categorical_accuracy: 0.7917
# Epoch 27/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7536 - categorical_accuracy: 0.8150
# Epoch 28/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7137 - categorical_accuracy: 0.8433
# Epoch 29/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7021 - categorical_accuracy: 0.8400
# Epoch 30/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6818 - categorical_accuracy: 0.8367
# Epoch 31/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6673 - categorical_accuracy: 0.8367
# Epoch 32/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6585 - categorical_accuracy: 0.8267
# Epoch 33/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6450 - categorical_accuracy: 0.8433
# Epoch 34/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6305 - categorical_accuracy: 0.8267
# Epoch 35/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6078 - categorical_accuracy: 0.8517
# Epoch 36/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5778 - categorical_accuracy: 0.8517
# Epoch 37/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5606 - categorical_accuracy: 0.8633
# Epoch 38/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5527 - categorical_accuracy: 0.8717
# Epoch 39/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.5177 - categorical_accuracy: 0.8683
# Epoch 40/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4906 - categorical_accuracy: 0.8967
# Epoch 41/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4985 - categorical_accuracy: 0.8783
# Epoch 42/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4760 - categorical_accuracy: 0.8917
# Epoch 43/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4663 - categorical_accuracy: 0.8983
# Epoch 44/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4565 - categorical_accuracy: 0.8917
# Epoch 45/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4489 - categorical_accuracy: 0.8917
# Epoch 46/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4401 - categorical_accuracy: 0.8967
# Epoch 47/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4161 - categorical_accuracy: 0.9067
# Epoch 48/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4165 - categorical_accuracy: 0.9017
# Epoch 49/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4205 - categorical_accuracy: 0.9033
# Epoch 50/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3838 - categorical_accuracy: 0.9133
# Epoch 51/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3732 - categorical_accuracy: 0.9183
# Epoch 52/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3633 - categorical_accuracy: 0.9283
# Epoch 53/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3597 - categorical_accuracy: 0.9250
# Epoch 54/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3417 - categorical_accuracy: 0.9267
# Epoch 55/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3494 - categorical_accuracy: 0.9117
# Epoch 56/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3236 - categorical_accuracy: 0.9300
# Epoch 57/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3220 - categorical_accuracy: 0.9250
# Epoch 58/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3131 - categorical_accuracy: 0.9350
# Epoch 59/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3131 - categorical_accuracy: 0.9433
# Epoch 60/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3101 - categorical_accuracy: 0.9283
# Epoch 61/2000
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2825 - categorical_accuracy: 0.9517
# Epoch 62/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2865 - categorical_accuracy: 0.9450
# Epoch 63/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2864 - categorical_accuracy: 0.9333
# Epoch 64/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2876 - categorical_accuracy: 0.9300
# Epoch 65/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2813 - categorical_accuracy: 0.9267
# Epoch 66/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2777 - categorical_accuracy: 0.9367
# Epoch 67/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.2633 - categorical_accuracy: 0.9533
# Epoch 68/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2473 - categorical_accuracy: 0.9550
# Epoch 69/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2621 - categorical_accuracy: 0.9333
# Epoch 70/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2551 - categorical_accuracy: 0.9467
# Epoch 71/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2411 - categorical_accuracy: 0.9500
# Epoch 72/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2274 - categorical_accuracy: 0.9600
# Epoch 73/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2223 - categorical_accuracy: 0.9533
# Epoch 74/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2084 - categorical_accuracy: 0.9717
# Epoch 75/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2239 - categorical_accuracy: 0.9550
# Epoch 76/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2210 - categorical_accuracy: 0.9583
# Epoch 77/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2030 - categorical_accuracy: 0.9667
# Epoch 78/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1866 - categorical_accuracy: 0.9700
# Epoch 79/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1983 - categorical_accuracy: 0.9667
# Epoch 80/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2042 - categorical_accuracy: 0.9667
# Epoch 81/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1939 - categorical_accuracy: 0.9683
# Epoch 82/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1933 - categorical_accuracy: 0.9650
# Epoch 83/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1889 - categorical_accuracy: 0.9617
# Epoch 84/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1768 - categorical_accuracy: 0.9717
# Epoch 85/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1843 - categorical_accuracy: 0.9683
# Epoch 86/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1651 - categorical_accuracy: 0.9683
# Epoch 87/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1854 - categorical_accuracy: 0.9633
# Epoch 88/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1632 - categorical_accuracy: 0.9800
# Epoch 89/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1820 - categorical_accuracy: 0.9567
# Epoch 90/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1716 - categorical_accuracy: 0.9683
# Epoch 91/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1757 - categorical_accuracy: 0.9617
# Epoch 92/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1787 - categorical_accuracy: 0.9667
# Epoch 93/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1598 - categorical_accuracy: 0.9767
# Epoch 94/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1575 - categorical_accuracy: 0.9767
# Epoch 95/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1569 - categorical_accuracy: 0.9750
# Epoch 96/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1512 - categorical_accuracy: 0.9717
# Epoch 97/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1476 - categorical_accuracy: 0.9717
# Epoch 98/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1519 - categorical_accuracy: 0.9783
# Epoch 99/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1438 - categorical_accuracy: 0.9683
# Epoch 100/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1343 - categorical_accuracy: 0.9783
# Epoch 101/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1364 - categorical_accuracy: 0.9733
# Epoch 102/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1383 - categorical_accuracy: 0.9783
# Epoch 103/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1302 - categorical_accuracy: 0.9817
# Epoch 104/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1402 - categorical_accuracy: 0.9767
# Epoch 105/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1269 - categorical_accuracy: 0.9883
# Epoch 106/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1243 - categorical_accuracy: 0.9817
# Epoch 107/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1262 - categorical_accuracy: 0.9783
# Epoch 108/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1176 - categorical_accuracy: 0.9883
# Epoch 109/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1153 - categorical_accuracy: 0.9817
# Epoch 110/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1213 - categorical_accuracy: 0.9833
# Epoch 111/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1219 - categorical_accuracy: 0.9833
# Epoch 112/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1162 - categorical_accuracy: 0.9850
# Epoch 113/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1097 - categorical_accuracy: 0.9883
# Epoch 114/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1167 - categorical_accuracy: 0.9817
# Epoch 115/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1095 - categorical_accuracy: 0.9867
# Epoch 116/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1137 - categorical_accuracy: 0.9800
# Epoch 117/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1170 - categorical_accuracy: 0.9817
# Epoch 118/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1093 - categorical_accuracy: 0.9883
# Epoch 119/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0949 - categorical_accuracy: 0.9883
# Epoch 120/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1008 - categorical_accuracy: 0.9883
# Epoch 121/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1032 - categorical_accuracy: 0.9850
# Epoch 122/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1049 - categorical_accuracy: 0.9833
# Epoch 123/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0981 - categorical_accuracy: 0.9867
# Epoch 124/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1116 - categorical_accuracy: 0.9750
# Epoch 125/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1005 - categorical_accuracy: 0.9850
# Epoch 126/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0920 - categorical_accuracy: 0.9867
# Epoch 127/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1053 - categorical_accuracy: 0.9817
# Epoch 128/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0952 - categorical_accuracy: 0.9817
# Epoch 129/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0912 - categorical_accuracy: 0.9850
# Epoch 130/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0893 - categorical_accuracy: 0.9850
# Epoch 131/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0928 - categorical_accuracy: 0.9817
# Epoch 132/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0817 - categorical_accuracy: 0.9917
# Epoch 133/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0780 - categorical_accuracy: 0.9900
# Epoch 134/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0771 - categorical_accuracy: 0.9917
# Epoch 135/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0756 - categorical_accuracy: 0.9900
# Epoch 136/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0762 - categorical_accuracy: 0.9917
# Epoch 137/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0754 - categorical_accuracy: 0.9900
# Epoch 138/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0779 - categorical_accuracy: 0.9883
# Epoch 139/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0797 - categorical_accuracy: 0.9933
# Epoch 140/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0776 - categorical_accuracy: 0.9883
# Epoch 141/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0684 - categorical_accuracy: 0.9917
# Epoch 142/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0712 - categorical_accuracy: 0.9883
# Epoch 143/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0668 - categorical_accuracy: 0.9917
# Epoch 144/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0678 - categorical_accuracy: 0.9900
# Epoch 145/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0729 - categorical_accuracy: 0.9883
# Epoch 146/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0683 - categorical_accuracy: 0.9883
# Epoch 147/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0744 - categorical_accuracy: 0.9917
# Epoch 148/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0689 - categorical_accuracy: 0.9867
# Epoch 149/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0668 - categorical_accuracy: 0.9950
# Epoch 150/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0632 - categorical_accuracy: 0.9900
# Epoch 151/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0591 - categorical_accuracy: 0.9950
# Epoch 152/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0617 - categorical_accuracy: 0.9950
# Epoch 153/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0642 - categorical_accuracy: 0.9883
# Epoch 154/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0632 - categorical_accuracy: 0.9950
# Epoch 155/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0640 - categorical_accuracy: 0.9917
# Epoch 156/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0616 - categorical_accuracy: 0.9917
# Epoch 157/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0582 - categorical_accuracy: 0.9950
# Epoch 158/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0592 - categorical_accuracy: 0.9983
# Epoch 159/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0568 - categorical_accuracy: 0.9883
# Epoch 160/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0580 - categorical_accuracy: 0.9917
# Epoch 161/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0553 - categorical_accuracy: 0.9933
# Epoch 162/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0532 - categorical_accuracy: 0.9950
# Epoch 163/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0516 - categorical_accuracy: 0.9983
# Epoch 164/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0532 - categorical_accuracy: 0.9967
# Epoch 165/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0530 - categorical_accuracy: 0.9950
# Epoch 166/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0496 - categorical_accuracy: 0.9933
# Epoch 167/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0541 - categorical_accuracy: 0.9933
# Epoch 168/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0591 - categorical_accuracy: 0.9933
# Epoch 169/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0617 - categorical_accuracy: 0.9883
# Epoch 170/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0435 - categorical_accuracy: 1.0000
# Epoch 171/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0448 - categorical_accuracy: 0.9967
# Epoch 172/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0464 - categorical_accuracy: 0.9967
# Epoch 173/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0427 - categorical_accuracy: 0.9967
# Epoch 174/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0391 - categorical_accuracy: 1.0000
# Epoch 175/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0430 - categorical_accuracy: 0.9983
# Epoch 176/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0381 - categorical_accuracy: 1.0000
# Epoch 177/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0389 - categorical_accuracy: 0.9983
# Epoch 178/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0417 - categorical_accuracy: 0.9983
# Epoch 179/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0525 - categorical_accuracy: 0.9900
# Epoch 180/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0453 - categorical_accuracy: 0.9950
# Epoch 181/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0408 - categorical_accuracy: 0.9950
# Epoch 182/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0397 - categorical_accuracy: 0.9967
# Epoch 183/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0407 - categorical_accuracy: 0.9983
# Epoch 184/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0354 - categorical_accuracy: 0.9967
# Epoch 185/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0344 - categorical_accuracy: 0.9967
# Epoch 186/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0340 - categorical_accuracy: 0.9983
# Epoch 187/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0337 - categorical_accuracy: 0.9983
# Epoch 188/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0349 - categorical_accuracy: 0.9983
# Epoch 189/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0377 - categorical_accuracy: 0.9933
# Epoch 190/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0348 - categorical_accuracy: 1.0000
# Epoch 191/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0373 - categorical_accuracy: 0.9950
# Epoch 192/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0392 - categorical_accuracy: 0.9950
# Epoch 193/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0341 - categorical_accuracy: 1.0000
# Epoch 194/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0303 - categorical_accuracy: 0.9983
# Epoch 195/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0312 - categorical_accuracy: 0.9967
# Epoch 196/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0325 - categorical_accuracy: 1.0000
# Epoch 197/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0314 - categorical_accuracy: 0.9967
# Epoch 198/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0315 - categorical_accuracy: 0.9950
# Epoch 199/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0337 - categorical_accuracy: 1.0000
# Epoch 200/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0316 - categorical_accuracy: 0.9983
# Epoch 201/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0312 - categorical_accuracy: 0.9983
# Epoch 202/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0279 - categorical_accuracy: 1.0000
# Epoch 203/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0273 - categorical_accuracy: 1.0000
# Epoch 204/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0289 - categorical_accuracy: 0.9983
# Epoch 205/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0332 - categorical_accuracy: 1.0000
# Epoch 206/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0373 - categorical_accuracy: 0.9950
# Epoch 207/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0385 - categorical_accuracy: 0.9950
# Epoch 208/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0322 - categorical_accuracy: 0.9983
# Epoch 209/2000
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0320 - categorical_accuracy: 0.9967
# Epoch 210/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0294 - categorical_accuracy: 0.9983
# Epoch 211/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0266 - categorical_accuracy: 1.0000
# Epoch 212/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0273 - categorical_accuracy: 0.9983
# Epoch 213/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0251 - categorical_accuracy: 0.9983
# Epoch 214/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0254 - categorical_accuracy: 1.0000
# Epoch 215/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0320 - categorical_accuracy: 0.9967
# Epoch 216/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0341 - categorical_accuracy: 0.9983
# Epoch 217/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0309 - categorical_accuracy: 0.9983
# Epoch 218/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0266 - categorical_accuracy: 1.0000
# Epoch 219/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0245 - categorical_accuracy: 1.0000
# Epoch 220/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0223 - categorical_accuracy: 1.0000
# Epoch 221/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0242 - categorical_accuracy: 0.9983
# Epoch 222/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0212 - categorical_accuracy: 1.0000
# Epoch 223/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0209 - categorical_accuracy: 0.9967
# Epoch 224/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0244 - categorical_accuracy: 0.9967
# Epoch 225/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0231 - categorical_accuracy: 1.0000
# Epoch 226/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0238 - categorical_accuracy: 1.0000
# Epoch 227/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0262 - categorical_accuracy: 0.9967
# Epoch 228/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0265 - categorical_accuracy: 0.9967
# Epoch 229/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0220 - categorical_accuracy: 0.9983
# Epoch 230/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0197 - categorical_accuracy: 1.0000
# Epoch 231/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0197 - categorical_accuracy: 1.0000
# Epoch 232/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0226 - categorical_accuracy: 1.0000
# Epoch 233/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0232 - categorical_accuracy: 0.9983
# Epoch 234/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0226 - categorical_accuracy: 0.9983
# Epoch 235/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0193 - categorical_accuracy: 0.9983
# Epoch 236/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0216 - categorical_accuracy: 0.9967
# Epoch 237/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0212 - categorical_accuracy: 0.9983
# Epoch 238/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0194 - categorical_accuracy: 1.0000
# Epoch 239/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0233 - categorical_accuracy: 0.9950
# Epoch 240/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0200 - categorical_accuracy: 0.9983
# Epoch 241/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0315 - categorical_accuracy: 0.9933
# Epoch 242/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0231 - categorical_accuracy: 0.9967
# Epoch 243/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0231 - categorical_accuracy: 0.9983
# Epoch 244/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0191 - categorical_accuracy: 0.9983
# Epoch 245/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0164 - categorical_accuracy: 1.0000
# Epoch 246/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0165 - categorical_accuracy: 1.0000
# Epoch 247/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0164 - categorical_accuracy: 1.0000
# Epoch 248/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0162 - categorical_accuracy: 0.9983
# Epoch 249/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0193 - categorical_accuracy: 0.9983
# Epoch 250/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0161 - categorical_accuracy: 1.0000
# Epoch 251/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0174 - categorical_accuracy: 1.0000
# Epoch 252/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0165 - categorical_accuracy: 1.0000
# Epoch 253/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0164 - categorical_accuracy: 1.0000
# Epoch 254/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0205 - categorical_accuracy: 0.9967
# Epoch 255/2000
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0213 - categorical_accuracy: 1.0000
# Epoch 256/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0179 - categorical_accuracy: 1.0000
# Epoch 257/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0153 - categorical_accuracy: 1.0000
# Epoch 258/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0145 - categorical_accuracy: 1.0000
# Epoch 259/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0149 - categorical_accuracy: 1.0000
# Epoch 260/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0175 - categorical_accuracy: 1.0000
# Epoch 261/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0158 - categorical_accuracy: 1.0000
# Epoch 262/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0143 - categorical_accuracy: 0.9983
# Epoch 263/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0154 - categorical_accuracy: 1.0000
# Epoch 264/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0142 - categorical_accuracy: 1.0000
# Epoch 265/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0135 - categorical_accuracy: 0.9983
# Epoch 266/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0130 - categorical_accuracy: 1.0000
# Epoch 267/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0125 - categorical_accuracy: 1.0000
# Epoch 268/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0124 - categorical_accuracy: 1.0000
# Epoch 269/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0120 - categorical_accuracy: 1.0000
# Epoch 270/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0124 - categorical_accuracy: 1.0000
# Epoch 271/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0120 - categorical_accuracy: 1.0000
# Epoch 272/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0121 - categorical_accuracy: 1.0000
# Epoch 273/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0116 - categorical_accuracy: 1.0000
# Epoch 274/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0107 - categorical_accuracy: 1.0000
# Epoch 275/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0118 - categorical_accuracy: 1.0000
# Epoch 276/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0137 - categorical_accuracy: 1.0000
# Epoch 277/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0170 - categorical_accuracy: 1.0000
# Epoch 278/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0142 - categorical_accuracy: 1.0000
# Epoch 279/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0132 - categorical_accuracy: 1.0000
# Epoch 280/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0133 - categorical_accuracy: 1.0000
# Epoch 281/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0110 - categorical_accuracy: 1.0000
# Epoch 282/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0111 - categorical_accuracy: 1.0000
# Epoch 283/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0098 - categorical_accuracy: 1.0000
# Epoch 284/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0100 - categorical_accuracy: 1.0000
# Epoch 285/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0105 - categorical_accuracy: 1.0000
# Epoch 286/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0100 - categorical_accuracy: 1.0000
# Epoch 287/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0101 - categorical_accuracy: 0.9983
# Epoch 288/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0146 - categorical_accuracy: 0.9983
# Epoch 289/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0175 - categorical_accuracy: 0.9967
# Epoch 290/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0204 - categorical_accuracy: 0.9967
# Epoch 291/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0201 - categorical_accuracy: 0.9967
# Epoch 292/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0122 - categorical_accuracy: 1.0000
# Epoch 293/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0118 - categorical_accuracy: 1.0000
# Epoch 294/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0109 - categorical_accuracy: 1.0000
# Epoch 295/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0106 - categorical_accuracy: 1.0000
# Epoch 296/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0079 - categorical_accuracy: 1.0000
# Epoch 297/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0091 - categorical_accuracy: 1.0000
# Epoch 298/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0109 - categorical_accuracy: 1.0000
# Epoch 299/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0089 - categorical_accuracy: 1.0000
# Epoch 300/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0086 - categorical_accuracy: 1.0000
# Epoch 301/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0104 - categorical_accuracy: 0.9983
# Epoch 302/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0082 - categorical_accuracy: 1.0000
# Epoch 303/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0079 - categorical_accuracy: 1.0000
# Epoch 304/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0094 - categorical_accuracy: 1.0000
# Epoch 305/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0095 - categorical_accuracy: 1.0000
# Epoch 306/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0077 - categorical_accuracy: 1.0000
# Epoch 307/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0074 - categorical_accuracy: 1.0000
# Epoch 308/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0074 - categorical_accuracy: 1.0000
# Epoch 309/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0074 - categorical_accuracy: 1.0000
# Epoch 310/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0073 - categorical_accuracy: 1.0000
# Epoch 311/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0099 - categorical_accuracy: 0.9983
# Epoch 312/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0097 - categorical_accuracy: 0.9983
# Epoch 313/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0084 - categorical_accuracy: 1.0000
# Epoch 314/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0077 - categorical_accuracy: 1.0000
# Epoch 315/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0076 - categorical_accuracy: 1.0000
# Epoch 316/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 317/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0082 - categorical_accuracy: 1.0000
# Epoch 318/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0072 - categorical_accuracy: 1.0000
# Epoch 319/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0069 - categorical_accuracy: 1.0000
# Epoch 320/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 321/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 322/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0069 - categorical_accuracy: 1.0000
# Epoch 323/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0066 - categorical_accuracy: 1.0000
# Epoch 324/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0064 - categorical_accuracy: 1.0000
# Epoch 325/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 326/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0063 - categorical_accuracy: 1.0000
# Epoch 327/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0066 - categorical_accuracy: 1.0000
# Epoch 328/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0063 - categorical_accuracy: 1.0000
# Epoch 329/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0063 - categorical_accuracy: 1.0000
# Epoch 330/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 331/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0062 - categorical_accuracy: 1.0000
# Epoch 332/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0058 - categorical_accuracy: 1.0000
# Epoch 333/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 334/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0054 - categorical_accuracy: 1.0000
# Epoch 335/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0058 - categorical_accuracy: 1.0000
# Epoch 336/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0054 - categorical_accuracy: 1.0000
# Epoch 337/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 338/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0056 - categorical_accuracy: 1.0000
# Epoch 339/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 340/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0057 - categorical_accuracy: 1.0000
# Epoch 341/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 342/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0097 - categorical_accuracy: 0.9983
# Epoch 343/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0149 - categorical_accuracy: 0.9967
# Epoch 344/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0464 - categorical_accuracy: 0.9883
# Epoch 345/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2402 - categorical_accuracy: 0.9233
# Epoch 346/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2596 - categorical_accuracy: 0.9200
# Epoch 347/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0911 - categorical_accuracy: 0.9667
# Epoch 348/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0630 - categorical_accuracy: 0.9817
# Epoch 349/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0381 - categorical_accuracy: 0.9883
# Epoch 350/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - categorical_accuracy: 1.0000
# Epoch 351/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0121 - categorical_accuracy: 1.0000
# Epoch 352/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0074 - categorical_accuracy: 1.0000
# Epoch 353/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0064 - categorical_accuracy: 1.0000
# Epoch 354/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0059 - categorical_accuracy: 1.0000
# Epoch 355/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0058 - categorical_accuracy: 1.0000
# Epoch 356/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0054 - categorical_accuracy: 1.0000
# Epoch 357/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0057 - categorical_accuracy: 1.0000
# Epoch 358/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0056 - categorical_accuracy: 1.0000
# Epoch 359/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0056 - categorical_accuracy: 1.0000
# Epoch 360/2000
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0053 - categorical_accuracy: 1.0000
# Epoch 361/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0049 - categorical_accuracy: 1.0000
# Epoch 362/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0051 - categorical_accuracy: 1.0000
# Epoch 363/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0052 - categorical_accuracy: 1.0000
# Epoch 364/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0047 - categorical_accuracy: 1.0000
# Epoch 365/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0045 - categorical_accuracy: 1.0000
# Epoch 366/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0045 - categorical_accuracy: 1.0000
# Epoch 367/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0044 - categorical_accuracy: 1.0000
# Epoch 368/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0045 - categorical_accuracy: 1.0000
# Epoch 369/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0044 - categorical_accuracy: 1.0000
# Epoch 370/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 371/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0046 - categorical_accuracy: 1.0000
# Epoch 372/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0044 - categorical_accuracy: 1.0000
# Epoch 373/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 374/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0041 - categorical_accuracy: 1.0000
# Epoch 375/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0044 - categorical_accuracy: 1.0000
# Epoch 376/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0047 - categorical_accuracy: 1.0000
# Epoch 377/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0041 - categorical_accuracy: 1.0000
# Epoch 378/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 379/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 380/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 381/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 382/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0043 - categorical_accuracy: 1.0000
# Epoch 383/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 384/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 385/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0041 - categorical_accuracy: 1.0000
# Epoch 386/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 387/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0037 - categorical_accuracy: 1.0000
# Epoch 388/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 389/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0037 - categorical_accuracy: 1.0000
# Epoch 390/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 391/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 392/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 393/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 394/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 395/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 396/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 397/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 398/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 399/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 400/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 401/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 402/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 403/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 404/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 405/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 406/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 407/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 408/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 409/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 410/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 411/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 412/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 413/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 414/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 415/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 416/2000
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 417/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 418/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 419/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 420/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 421/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 422/2000
# ...
# Epoch 1867/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2447e-05 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.2770e-05 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 1.2503e-05 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.2419e-05 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.2183e-05 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2090e-05 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2154e-05 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1982e-05 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2084e-05 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1607e-05 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1953e-05 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2189e-05 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1544e-05 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 19/19 [==============================] - 0s 9ms/step - loss: 1.1387e-05 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1573e-05 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1716e-05 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1987e-05 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1909e-05 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 1.1525e-05 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2440e-05 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3395e-05 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 1.1733e-05 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2143e-05 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0885e-05 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1204e-05 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0882e-05 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1090e-05 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1391e-05 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0766e-05 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0939e-05 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0964e-05 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0965e-05 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1430e-05 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0394e-05 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 1.1750e-05 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 19/19 [==============================] - 0s 9ms/step - loss: 1.1259e-05 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0265e-05 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0551e-05 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0844e-05 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0047e-05 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 9.7959e-06 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0029e-05 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0791e-05 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0056e-05 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0585e-05 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 1.0106e-05 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 9.9221e-06 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 9.7377e-06 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 9.9381e-06 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 9.4663e-06 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0515e-05 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 9.4591e-06 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 9.7782e-06 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 9.8966e-06 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 9.9063e-06 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1100e-05 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 9.6466e-06 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 9.0348e-06 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 8.9949e-06 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 9.1577e-06 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 19/19 [==============================] - 0s 9ms/step - loss: 9.4345e-06 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 9.1874e-06 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 8.9533e-06 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 9.4542e-06 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 1.0437e-05 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 9.5908e-06 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 9.5290e-06 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 8.8455e-06 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 8.5580e-06 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 9.1042e-06 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0217e-05 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 8.6289e-06 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 8.3657e-06 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 8.5073e-06 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 8.2781e-06 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 8.0587e-06 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 8.1356e-06 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 19/19 [==============================] - 0s 9ms/step - loss: 7.8680e-06 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 8.6608e-06 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 8.4092e-06 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 8.5494e-06 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 8.5729e-06 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 7.7130e-06 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 7.9348e-06 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 7.8946e-06 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 9.1163e-06 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 8.8664e-06 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 7.4152e-06 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 7.4013e-06 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 7.6314e-06 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 7.5408e-06 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 7.7291e-06 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 7.9296e-06 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 8.2660e-06 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 8.1014e-06 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 7.5583e-06 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 7.7613e-06 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 7.6586e-06 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 7.9377e-06 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 8.9893e-06 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 2.6108e-05 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3576 - categorical_accuracy: 0.9350
# Epoch 1969/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5717 - categorical_accuracy: 0.8850
# Epoch 1970/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.1296 - categorical_accuracy: 0.9633
# Epoch 1971/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0296 - categorical_accuracy: 0.9917
# Epoch 1972/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0127 - categorical_accuracy: 0.9933
# Epoch 1973/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 9.1882e-04 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 7.4233e-04 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 6.4511e-04 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 5.8865e-04 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 5.3958e-04 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 5.0719e-04 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 4.7648e-04 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 4.5621e-04 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 4.3378e-04 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 4.1724e-04 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 4.0015e-04 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 3.8688e-04 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 3.7397e-04 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 3.6222e-04 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 3.5158e-04 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 3.4120e-04 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 3.3471e-04 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 19/19 [==============================] - 0s 7ms/step - loss: 3.2488e-04 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 3.1603e-04 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0990e-04 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0158e-04 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9540e-04 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 19/19 [==============================] - 0s 4ms/step - loss: 2.8945e-04 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 19/19 [==============================] - 0s 9ms/step - loss: 2.8496e-04 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 19/19 [==============================] - 0s 8ms/step - loss: 2.7811e-04 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 19/19 [==============================] - 0s 6ms/step - loss: 2.7373e-04 - categorical_accuracy: 1.0000

# %%
# Plot epoch vs accuracy
plt.plot(history.history['categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# Plot epoch vs loss
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

#saving the model
model.save("Final_Tf_mp_model")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Final_Tf_mp_model\assets
# INFO:tensorflow:Assets written to: Final_Tf_mp_model\assets

# %%
model = tf.keras.models.load_model('Final_Tf_mp_model')

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 61, 32)            6080
#
#  max_pooling1d_1 (MaxPooling  (None, 30, 32)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 960)               0
#
#  dense_1 (Dense)             (None, 30)                28830
#
# =================================================================
# Total params: 34,910
# Trainable params: 34,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(X_test)

print("X_test shape: ", X_test.shape)
# Out:
# 5/5 [==============================] - 0s 3ms/step
# X_test shape:  (150, 63, 63)

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

yhat = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[144,   1],
#         [  0,   5]],
#
#        [[144,   2],
#         [  0,   4]],
#
#        [[145,   0],
#         [  0,   5]],
#
#        [[145,   1],
#         [  1,   3]],
#
#        [[145,   1],
#         [  0,   4]],
#
#        [[146,   1],
#         [  0,   3]],
#
#        [[142,   0],
#         [  4,   4]],
#
#        [[148,   0],
#         [  0,   2]],
#
#        [[142,   4],
#         [  0,   4]],
#
#        [[147,   0],
#         [  0,   3]],
#
#        [[144,   0],
#         [  1,   5]],
#
#        [[143,   1],
#         [  3,   3]],
#
#        [[146,   0],
#         [  0,   4]],
#
#        [[143,   0],
#         [  0,   7]],
#
#        [[146,   0],
#         [  0,   4]],
#
#        [[145,   0],
#         [  0,   5]],
#
#        [[146,   0],
#         [  0,   4]],
#
#        [[143,   0],
#         [  0,   7]],
#
#        [[140,   0],
#         [  2,   8]],
#
#        [[146,   0],
#         [  0,   4]],
#
#        [[142,   0],
#         [  0,   8]],
#
#        [[146,   0],
#         [  0,   4]],
#
#        [[144,   0],
#         [  0,   6]],
#
#        [[143,   0],
#         [  1,   6]],
#
#        [[143,   1],
#         [  0,   6]],
#
#        [[144,   0],
#         [  2,   4]],
#
#        [[144,   1],
#         [  0,   5]],
#
#        [[146,   1],
#         [  0,   3]],
#
#        [[148,   0],
#         [  0,   2]],
#
#        [[145,   1],
#         [  1,   3]]], dtype=int64)

# %%
print("Improved accuracy without validation datatsets", accuracy_score(ytrue, yhat))
# Out:
# Improved accuracy without validation datatsets 0.9

# %%
mp_hands = mp.solutions.hands
with mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5) as hands:
    vidcap = cv2.VideoCapture('/content/drive/MyDrive/MediaPipe_Data/Test_Video_MediaPipe/love_P5_1.mp4')
    success,frame = vidcap.read()
    count = 0
    test = []
    while success:     
        success,frame = vidcap.read()
        if success:
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = hands.process(image)
            if results.multi_hand_landmarks:
                for hand_landmarks in results.multi_hand_landmarks:
                    landmarks = hand_landmarks.landmark
                    landmarks_array = np.array([[landmark.x, landmark.y, landmark.z] for landmark in landmarks])
                    test.append(landmarks_array.flatten())

nptest = np.array([test[:35]])

print("test shape: ", nptest.shape)
# Out:
# test shape:  (1, 0)

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# # Predict the labels of the test data
# yhat = model.predict(X_test)
# y_pred_classes = np.argmax(yhat, axis=1)

# # Convert the one-hot encoded labels to integers
# y_test_classes = np.argmax(y_test, axis=1)

# Get the classification report
print(classification_report(ytrue, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       0.67      1.00      0.80         4
#            2       1.00      1.00      1.00         5
#            3       0.75      0.75      0.75         4
#            4       0.80      1.00      0.89         4
#            5       0.75      1.00      0.86         3
#            6       1.00      0.50      0.67         8
#            7       1.00      1.00      1.00         2
#            8       0.50      1.00      0.67         4
#            9       1.00      1.00      1.00         3
#           10       1.00      0.83      0.91         6
#           11       0.75      0.50      0.60         6
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         7
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         5
#           16       1.00      1.00      1.00         4
#           17       1.00      1.00      1.00         7
#           18       1.00      0.80      0.89        10
#           19       1.00      1.00      1.00         4
#           20       1.00      1.00      1.00         8
#           21       1.00      1.00      1.00         4
#           22       1.00      1.00      1.00         6
#           23       1.00      0.86      0.92         7
#           24       0.86      1.00      0.92         6
#           25       1.00      0.67      0.80         6
#           26       0.83      1.00      0.91         5
#           27       0.75      1.00      0.86         3
#           28       1.00      1.00      1.00         2
#           29       0.75      0.75      0.75         4
#
#     accuracy                           0.90       150
#    macro avg       0.91      0.92      0.90       150
# weighted avg       0.92      0.90      0.90       150

# %%
# Get the test accuracy
test_acc = model.evaluate(X_test, y_test)[1]
print("Test accuracy:", test_acc)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4375 - categorical_accuracy: 0.9000
# Test accuracy: 0.8999999761581421

# %%
# Get the test proportion
test_proportion = len(X_test) / (len(X_train) + len(X_test))
print("Test proportion:", test_proportion)
# Out:
# Test proportion: 0.2

# %%
# Get the confusion matrix
cm = confusion_matrix(ytrue, yhat)

# Plot the confusion matrix as an image
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=words, yticklabels=words)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
# Get the recall (weighted), f1 score (weighted), and precision (weighted)
weighted_metrics = classification_report(ytrue, yhat, output_dict=True)['weighted avg']
print("Weighted recall:", weighted_metrics['recall'])
print("Weighted f1 score:", weighted_metrics['f1-score'])
print("Weighted precision:", weighted_metrics['precision'])
# Out:
# Weighted recall: 0.9
# Weighted f1 score: 0.8982183742183741
# Weighted precision: 0.9222857142857142
